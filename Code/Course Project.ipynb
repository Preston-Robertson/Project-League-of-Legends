# %% [markdown]
# # IE 8623 Course Project
# ***

# %% [markdown]
# # Data Descritption
# ***

# %% [markdown]
# ## Introduction to the Dataset

# %% [markdown]
# This dataset is on an online competitve game called League of Legends. I chose this dataset because I wanted to challenge myself with your project and force me to use things that I have learned from all my classes this semester. This dataset has 23,752 data points and 24 features (or columns). This is a complicated dataset, with several variables requiring me to use feature reduction to run the code while also being large enough to have a correlation. This dataset was specifically chosen once I decided to challenge myself because I play this video game allowing me to get straight into analysis and I do not have to worry about interpreting the results.
#
#
# ***

# %% [markdown]
# ## <font color=red> Description of League of Legends (Supplementary Information to help/ Not necessary to read).</font>

# %% [markdown]
# ### Brief Description of League of Legends
# League of Legends is a part of the MOBA genre of games and is considered the most widely popular game of all time. In it's most recent tournaments making more money than the Superbowl.
#
# ### Objective
# League of Legends is an online competitive multiplayer game where two teams fight destroy the enemy nexus.
# Note: All things stated in this description can be seen below.
#
# ### Map of League of Legends
# ![image.png](attachment:image.png)
#
# ### Description of the Map
# The map of league of legends contains 3 paths, each of these are a lane with a corresponding name. These are named Top Lane, Mid Lane (short for Middle), and Bot Lane (short for Bottom Lane). Each lane spawns "minions" to help push lanes. These minions are very easy monsters and provide gold if you land the killing blow. Each one of these lanes have 3 towers and an inhibitor. All three of one lanes tower + inhibitor need to be destroyed before you can reach the nexus. The towers provide protection to players by hurting enemy champions when they are in range.
# The inhibitor provides no uses to ally team; however, if you destroy the enemy inhibitor then in that lane "Super Minions" will spawn. These buffed minions help push to finish the game.
#
# There are also forests in the middle of these lanes. This is called the Jungle. In the jungle there are several monsters’ worth gold and that grow stronger as the game goes on. Some monsters, if killed, can even provide special bonuses. All these monsters can be killed by one player.
#
# The part that splits the map into two sides is known as the river. This is the equivalent of the half-way line in soccer. In this part of the map Large Monsters spawn that require a group effort to takedown but give huge bonuses.
#
#
# ### Gameplay of League of Legends
#
# The game is known for it's complexity and if you want a comprehensive guide I have provided a link that I think does an excellent job. I will explain the bare necessities needed to follow the data.
# https://mobalytics.gg/blog/absolute-beginners-guide-to-league-of-legends/
#
# There are 5 players on each team, each player plays a champion. This champion is a character with unique gameplay, stats, and abilities. These 5 players will each fill a specific role: Top Lane goes to the Top Lane, Mid Lane goes to the Mid Lane, the Jungler goes to the Jungle, the Attack Damage Carry (ADC) and Support goes to the Bot Lane. In each of their respective locations each role attempts to make gold and level up.
#
# The gold is used to buy items (each with unique effects and every champion picks from the same pool of items), which means the more gold you have the more items you can buy. You get gold by killing different things on the map (for example: minions, monsters, large monsters, and enemy players) and can also be obtained by everyone at a constant passive rate. The more items you have the stronger you are and more capable you and your team are to win the game.
#
# Levels occur naturally when you gain experience by being around combat or by killing enemy units (same as gold) this however does not passively increase and must be earned. With each level up you basic stats become stronger which means you are stronger and allows you to level up current abilities or unlock new abilities.
#
# There are several other factors to the game, but I think this basic grasp is all that is needed to understand the data.
#
#
#
# ## <font color=red>End of Supplementary Information
# ***

# %% [markdown]
# ## Data Description / Project Proposal
#
#
# ### Question 1
#
# This data set was recorded last year and was recorded at the highest level of gameplay (pros and high-ranking players). This data set recorded 24 different features from each game. The most important to us is the Boolean value "Win" this is our output data point since this is the most important factor in a competitive format.
#
#
# The other 23 features (the input values are):
# **Unnamed: 0** == This feature represents the player that they recorded the data from (anonymized)
#
# **Champ** == This is a string value that represents the champion that Unamed was playing
#
# **Team** == This is a boolean value that states which team the player was playing (Red or Blue)
#
# **GoldEarned** == A numeric value that represent the total money earned by Unamed
#
# **Kills** == A numeric value that represents the total enemy champions killed by Unamed
#
# **Deaths** == A numeric value that represents the number of deaths Unamed had
#
# **Assists** == A numeric value that represents the total enemy champions Unamed help kill but did not finish
#
# **totalDamageDealtToChampions** == A numeric value that represents the amount of damage done by Unamed to champions
#
# **damageDealtToTurrets** == A numeric value that represents the amount of damage done by Unamed to turrets
#
# **visionScore** ==  A numeric value that represents the amount of vision score, Unamed had
#
# **totalDamageTaken** ==  A numeric value that represents the amount of damage taken by Unamed from enemy champions
#
# **turretKills** ==  A numeric value that represents the amount of turrets destroyed by Unamed
#
# **inhibitorKills** ==  A numeric value that represents the amount
#
# **totalMinionsKilled** ==  A numeric value that represents the amount of minions Unamed had the killing blow on
#
# **champLevel** ==  A numeric value that represents the level of Unamed when the game was over
#
# **wardsPlaced** ==  A numeric value that represents the amount of wards placed by Unamed
#
# **firstBloodKill** == A Boolean value that represents if Unamed got the first blood of the match
#
# **firstBloodAssist** == A Boolean value that represent if Unamed assisted with the first blood of the match
#
# **WRgeneral** ==  A percentage value that represents Unamed's personal winrate before the match
#
# **WRchamp** == A percentage value that represents Unamed's champion's winrate before the match (from all players)
#
# **Duration_secs** == A time value that represents the length of the game
#
# **Position** == A string value that represents the position of Unamed
#
# **Role** == A string value that represents the number of players that Unamed chose to play with
#
#
# There are no missing variables, see below in the code.
# ![image.png](attachment:image.png)
#
# Since I am specifically analyzing the 'Win' variable which is a Boolean value. **I am using classification to try and predict a win before that game even starts.**
#
#
# ### Question 2
#
# I am currently planning on using **Decision Trees, K-Nearest Neighbors, and Support Vector Machines** to try and find the best results. I will also attempt **Naive Bayes Classifier**; however, I am not expecting great results. The final method I will attempt is a **Neural Network**. This one should have the best result for this data set.
#
#
# ### Question 3
#
# Below is the **cardinality** of the variables to show the number of unique variables.
# ![image-2.png](attachment:image-2.png)
#
# Below is the **correlation matrix** to show how each data point interacts in an easily digestible manner. This helps show that the data set is very correlated since all things money, kills, assists, etc. increase with time. Also, gold and level increases with kills, assist, time, etc. Shows why Machine Learning Algorithms are needed to analyze the data.
# ![image-3.png](attachment:image-3.png)
#
# Below is the **scatter plot** ([Basic Evaluation of Dataset], double click the bracketed text) of the data to see early relationships of the data, however the 24x24 graph is too large to fit up here, so you will need to scroll down through the code. Sorry I will fix this before the final draft.
#
#
# ### Question 4
#
# The **Objective** of this code is intended to use to help balance the game. What champions are doing too much damage, and what role is dying too much. How are each of these interactions effecting the game. If the game is perfectly balanced, then the Machine Learning Algorithms should output a 50% prediction rate to show that it is truly guessing and that specific features in the game are not too powerful or too weak allowing for fair games and allow the players freedom to do what the players want (without worrying if it is the most powerful). Since I play the game, I know that will not be the case. So my further objective is making a Neural Network attempt to predict what balances should and should not be made to the game.
#
#
# ### Final
#
# Below is all the code that was used to show the results above plus some supplemental information that I chose not to include for the sake of brevity. There are also some feature engineering steps I have taken to make the code run faster and put the dataset in the correct format. I have also already ran a SVM with a sigmoid kernel.
#
# [Data Fixing]
# [Basic Evaluation of Dataset]
# [Machine Learning Techniques]

# %% [markdown]
# # Code

# %% [markdown]
# ##  Loading Libraries

# %%
# Import Pyspark

import findspark
findspark.init()
findspark.find()
import pyspark
findspark.find()
# Out:
# 'C:\\Spark\\spark-3.1.2-bin-hadoop3.2'

# %%
# Import Pyspark 

from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Crosslisted_Project").getOrCreate()
from pyspark.sql.functions import approxCountDistinct, countDistinct, count, when, isnan, col, isnull

# %%
# Importing Libraries



# Basic Libraries #################################################################################################
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 
import seaborn as sns

# For Feature Engineering #########################################################################################

# For Plotting Correlation Matrix and Scatter Plot
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

# For PCA
from pyspark.ml.feature import PCA
from pyspark.ml.linalg import Vectors
from pyspark.ml.functions import vector_to_array

# For String Indexer
from pyspark.ml.feature import StringIndexer
from pyspark.ml import Pipeline

# For Vector Assembler
from pyspark.ml.feature import VectorAssembler


# For Machine Learning Techniques #################################################################################

# For Data Anaylsis
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# For SVM
from sklearn import svm
from sklearn.svm import SVC
from sklearn.svm import SVR

# For KNN 
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from sklearn.neighbors import NearestCentroid
from sklearn.pipeline import Pipeline

# For Desicion Trees 
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor

# For Random Forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# For Neural Network 


# Personal Preference #############################################################################################
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Uploading Dataset

# %%
# Select dataset below

dataset_file = "base_def.csv"

# %%
# Uploading dataset as a Pandas file

df_pd = pd.read_csv(dataset_file)

df_pd.head(5)
# Out:
#    Unnamed: 0     Champ  Team  GoldEarned  Kills  Deaths  Assists    Win  \
# 0           1     Garen   100       10913      3      13        6  False
# 1           2    Irelia   100       11004     10       3        3   True
# 2           3      Kayn   100       13191     10       8       15   True
# 3           4  Tristana   100        7025      2       6        3  False
# 4           5      Jhin   200       10867      4       4        8   True
#
#    totalDamageDealtToChampions  damageDealtToTurrets  ...  totalMinionsKilled  \
# 0                        14015                     0  ...                 205
# 1                        13895                  6226  ...                 162
# 2                        29583                  2259  ...                  33
# 3                        11439                   793  ...                 138
# 4                        13623                   800  ...                 158
#
# ...

# %%
# Uploading dataset as a Pyspark file

file_location = dataset_file
file_type = "csv"
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

df_sp = spark.read.format(file_type)\
.option("InferSchema", infer_schema)\
.option("header", first_row_is_header)\
.option("sep", delimiter)\
.load(file_location)

df_sp.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Champ: string (nullable = true)
#  |-- Team: integer (nullable = true)
#  |-- GoldEarned: integer (nullable = true)
#  |-- Kills: integer (nullable = true)
#  |-- Deaths: integer (nullable = true)
#  |-- Assists: integer (nullable = true)
#  |-- Win: boolean (nullable = true)
#  |-- totalDamageDealtToChampions: integer (nullable = true)
#  |-- damageDealtToTurrets: integer (nullable = true)
#  |-- visionScore: integer (nullable = true)
#  |-- totalDamageTaken: integer (nullable = true)
#  |-- turretKills: integer (nullable = true)
#  |-- inhibitorKills: integer (nullable = true)
#  |-- totalMinionsKilled: integer (nullable = true)
#  |-- champLevel: integer (nullable = true)
#  |-- wardsPlaced: integer (nullable = true)
#  |-- firstBloodKill: boolean (nullable = true)
#  |-- firstBloodAssist: boolean (nullable = true)
#  |-- WRgeneral: double (nullable = true)
#  |-- WRchamp: double (nullable = true)
# ...

# %% [markdown]
# ## Data Fixing

# %%
# Setting Variables

target_variable_name = 'Win'

# %%
# For future code, taking out the boolean value (pandas)

df_pd_noB = df_pd.select_dtypes(exclude='bool')

df_pd_noB.head(5)
# Out:
#    Unnamed: 0     Champ  Team  GoldEarned  Kills  Deaths  Assists  \
# 0           1     Garen   100       10913      3      13        6
# 1           2    Irelia   100       11004     10       3        3
# 2           3      Kayn   100       13191     10       8       15
# 3           4  Tristana   100        7025      2       6        3
# 4           5      Jhin   200       10867      4       4        8
#
#    totalDamageDealtToChampions  damageDealtToTurrets  visionScore  ...  \
# 0                        14015                     0           24  ...
# 1                        13895                  6226           10  ...
# 2                        29583                  2259           18  ...
# 3                        11439                   793           21  ...
# 4                        13623                   800           12  ...
#
#    turretKills  inhibitorKills  totalMinionsKilled  champLevel  wardsPlaced  \
# ...

# %%
# Setting the Boolean values to work with

df_pd["Win"] = df_pd["Win"].astype(int)
df_pd['firstBloodAssist'] = df_pd['firstBloodAssist'].astype(int)
df_pd['firstBloodKill'] = df_pd['firstBloodKill'].astype(int)

df_sp2 = spark.createDataFrame(df_pd)

# %%
# Setting the different dtypes into their own array (spark)

def variable_type(df_sp2):
    
    vars_list = df_sp2.dtypes
    char_vars = []
    num_vars = []
    bool_vars = []
    for i in vars_list:
        if i[1] in ('string'):
            char_vars.append(i[0])
        if i[1] in ('boolean'):
            bool_vars.append(i[0])
        else:
            num_vars.append(i[0])
    
    return char_vars, num_vars, bool_vars

char_vars, num_vars, bool_vars = variable_type(df_sp2)


print(char_vars)
print(num_vars)
print(bool_vars)
# Out:
# ['Champ', 'Position', 'Role']
# ['Unnamed: 0', 'Champ', 'Team', 'GoldEarned', 'Kills', 'Deaths', 'Assists', 'Win', 'totalDamageDealtToChampions', 'damageDealtToTurrets', 'visionScore', 'totalDamageTaken', 'turretKills', 'inhibitorKills', 'totalMinionsKilled', 'champLevel', 'wardsPlaced', 'firstBloodKill', 'firstBloodAssist', 'WRgeneral', 'WRchamp', 'Duration_secs', 'Position', 'Role']
# []

# %% [markdown]
# ## Basic Evaluation of Dataset

# %%
# The Length of the Dataset

len(df_pd)
# Out:
# 23752

# %%
# Basic Statistics of the Data

df_sp.describe().toPandas()
# Out:
#   summary                 _c0   Champ                Team          GoldEarned  \
# 0   count               23752   23752               23752               23752
# 1    mean  12613.528713371506    None  149.99157965644997  10223.871842371169
# 2  stddev    7437.00102708683    None   50.00105186714381   3479.974766959387
# 3     min                   1  Aatrox                 100                 666
# 4     max               25647    Zyra                 200               25133
#
#                Kills              Deaths            Assists  \
# 0              23752               23752              23752
# 1  5.011577972381273    4.96501347254968  7.434152913438869
# 2  3.977473388778818  2.8592067441124702  5.375719748310074
# 3                  0                   0                  0
# 4                 29                  20                 40
#
#   totalDamageDealtToChampions damageDealtToTurrets  ...         turretKills  \
# ...

# %%
# Cardinality of each Variable

def cardinality_calculation(df_sp2, cut_off=1):
    cardinality = df_sp2.select(*[approxCountDistinct(c).alias(c) for c in df_sp2.columns])
    
    ## convert to pandas for efficient calculations
    final_cardinality_df = cardinality.toPandas().transpose()
    final_cardinality_df.reset_index(inplace=True) 
    final_cardinality_df.rename(columns={0:'Cardinality'}, inplace=True) 
    
    vars_selected = final_cardinality_df['index'][final_cardinality_df['Cardinality'] <= cut_off] 
    
    return final_cardinality_df, vars_selected

cardinality_df, cardinality_vars_selected = cardinality_calculation(df_sp2)
cardinality_df
# Out:
#                           index  Cardinality
# 0                    Unnamed: 0        23381
# 1                         Champ          149
# 2                          Team            2
# 3                    GoldEarned        10655
# 4                         Kills           29
# 5                        Deaths           20
# 6                       Assists           39
# 7                           Win            2
# 8   totalDamageDealtToChampions        14948
# 9          damageDealtToTurrets         6507
# 10                  visionScore          141
# 11             totalDamageTaken        16294
# 12                  turretKills           10
# 13               inhibitorKills            5
# 14           totalMinionsKilled          361
# 15                   champLevel           18
# 16                  wardsPlaced           85
# 17               firstBloodKill            2
# 18             firstBloodAssist            1
# 19                    WRgeneral           79
# ...

# %%
# Missing Percentage

df_sp_noB = spark.createDataFrame(df_pd_noB)

def missing_calculation(df_sp_noB, miss_percentage=0.45):
    
    missing = df_sp_noB.select(*[count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df_sp_noB.columns])
    length_df = df_sp_noB.count()

    final_missing_df = missing.toPandas().transpose()
    final_missing_df.reset_index(inplace=True) 
    final_missing_df.rename(columns={0:'missing_count'}, inplace=True) 
    final_missing_df['missing_percentage'] = final_missing_df['missing_count']/length_df
    
    vars_selected = final_missing_df['index'][final_missing_df['missing_percentage'] >= miss_percentage] 
    
    return final_missing_df, vars_selected

missing_df, missing_vars_selected = missing_calculation(df_sp_noB)
missing_df
# Out:
#                           index  missing_count  missing_percentage
# 0                    Unnamed: 0              0                 0.0
# 1                         Champ              0                 0.0
# 2                          Team              0                 0.0
# 3                    GoldEarned              0                 0.0
# 4                         Kills              0                 0.0
# 5                        Deaths              0                 0.0
# 6                       Assists              0                 0.0
# 7   totalDamageDealtToChampions              0                 0.0
# 8          damageDealtToTurrets              0                 0.0
# 9                   visionScore              0                 0.0
# 10             totalDamageTaken              0                 0.0
# 11                  turretKills              0                 0.0
# 12               inhibitorKills              0                 0.0
# ...

# %%
# Correlation Matrix

fr_CorrM = df_pd #For Correlation Matrix

def plotCorrelationMatrix(fr_CorrM, graphWidth):
    filename = 'League of Legends Season 10'
    CorrM = fr_CorrM.dropna('columns')
    CorrM = CorrM[[col for col in fr_CorrM if fr_CorrM[col].nunique() > 1]] 
    if CorrM.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = CorrM.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()


plotCorrelationMatrix(fr_CorrM, 8)

# %%
# Scatter Plot of Data


scatterplot_df = df_pd

def plotScatterMatrix(scatterplot_df, plotSize, textSize):
    df = scatterplot_df.select_dtypes(include =[np.number]) 
    
    df = scatterplot_df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] 
    columnNames = list(df)
    if len(columnNames) > 10: 
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    #for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        #ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()
    


plotScatterMatrix(scatterplot_df, 20, 10)

# %% [markdown]
# ## Feature Extraction

# %%
df_pd.columns
# Out:
# Index(['Unnamed: 0', 'Champ', 'Team', 'GoldEarned', 'Kills', 'Deaths',
#        'Assists', 'Win', 'totalDamageDealtToChampions', 'damageDealtToTurrets',
#        'visionScore', 'totalDamageTaken', 'turretKills', 'inhibitorKills',
#        'totalMinionsKilled', 'champLevel', 'wardsPlaced', 'firstBloodKill',
#        'firstBloodAssist', 'WRgeneral', 'WRchamp', 'Duration_secs', 'Position',
#        'Role'],
#       dtype='object')

# %%
# StringIndexer to convert the String values to Numeric values

fr_strInd = df_sp


# Creating the function to index the string values
def category_to_index(fr_strInd, char_vars):

    char_df = fr_strInd.select(char_vars)
    indexers = [StringIndexer(inputCol=c, outputCol=c+"_index", handleInvalid="keep") for c in char_df.columns]
    pipeline = pyspark.ml.Pipeline(stages=indexers)
    char_labels = pipeline.fit(char_df)
    fr_strInd = char_labels.transform(fr_strInd)
    return fr_strInd, char_labels


# Finding the string values
fr_strInd, char_labels = category_to_index(fr_strInd, char_vars)

# Selecting the string values
fr_strInd = fr_strInd.select([c for c in fr_strInd.columns if c not in char_vars])


# Renaming Columns to show they have been indexed
def rename_columns(fr_strInd, char_vars):
    mapping = dict(zip([i + '_index' for i in char_vars], char_vars))
    fr_strInd = fr_strInd.select([col(c).alias(mapping.get(c, c)) for c in fr_strInd.columns])
    return fr_strInd

fr_strInd = rename_columns(fr_strInd, char_vars)


df_sp_indexed = fr_strInd

# Checking to make sure the above lines of code worked
df_pd_indexed = df_sp_indexed.toPandas()
df_pd_indexed.head(5)
# Out:
#    _c0  Team  GoldEarned  Kills  Deaths  Assists    Win  \
# 0    1   100       10913      3      13        6  False
# 1    2   100       11004     10       3        3   True
# 2    3   100       13191     10       8       15   True
# 3    4   100        7025      2       6        3  False
# 4    5   200       10867      4       4        8   True
#
#    totalDamageDealtToChampions  damageDealtToTurrets  visionScore  ...  \
# 0                        14015                     0           24  ...
# 1                        13895                  6226           10  ...
# 2                        29583                  2259           18  ...
# 3                        11439                   793           21  ...
# 4                        13623                   800           12  ...
#
#    champLevel  wardsPlaced  firstBloodKill  firstBloodAssist  WRgeneral  \
# 0          16           10           False             False     0.6000
# ...

# %%
# Heat Map

fr_hm = df_pd_indexed #For Heat Map

## Determining the relevancy of features using heatmap in calculating the outcome variable
corrmat = fr_hm.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))

#Plotting heat map
g=sns.heatmap(fr_hm[top_corr_features].corr(),annot=True,linewidths=.5)
b, t = plt.ylim() 
b += 0.5
t -= 0.5 
plt.ylim(b, t)
plt.title('Correlation Matrix',fontdict = {'fontsize' : 20})
plt.xticks(range(len(fr_hm.columns)), fr_hm.columns, rotation=90)
plt.yticks(range(len(fr_hm.columns)), fr_hm.columns)
plt.gca().xaxis.tick_bottom()
plt.show()

# %%
# Vector Assembler so that we can run PCA

df_sp_ind = spark.createDataFrame(df_pd_indexed)

def assemble_vectors(df_sp_ind, features_list, target_variable_name):
    stages = []

    assembler = VectorAssembler(inputCols=features_list, outputCol='features')
    stages = [assembler]
    selectedCols = [target_variable_name, 'features'] + features_list
    pipeline = Pipeline(stages=stages)
    assembleModel = pipeline.fit(df_sp_ind)
    df_sp_ind = assembleModel.transform(df_sp_ind).select(selectedCols)

    return df_sp_ind

# Setting the Feature List
features_list = df_sp_ind.columns
features_list.remove(target_variable_name)

# Assemble the Vectors
df_sp_asm = assemble_vectors(df_sp_ind, features_list, target_variable_name)

# Setting a Panda File, just in case
df_pd_asm = df_sp_asm.toPandas()

# Showing the features
df_sp_asm.select('features', 'Win').show(5, False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-ef7b21856bd2> in <module>
#      20
#      21 # Assemble the Vectors
# ---> 22 df_sp_asm = assemble_vectors(df_sp_ind, features_list, target_variable_name)
#      23
#      24 # Setting a Panda File, just in case
#
# <ipython-input-20-ef7b21856bd2> in assemble_vectors(df_sp_ind, features_list, target_variable_name)
#       9     stages = [assembler]
#      10     selectedCols = [target_variable_name, 'features'] + features_list
# ---> 11     pipeline = Pipeline(stages=stages)
#      12     assembleModel = pipeline.fit(df_sp_ind)
#      13     df_sp_ind = assembleModel.transform(df_sp_ind).select(selectedCols)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ...

# %%
# Normalizing the Data to speed up the code

# %% [raw]
# # Taken out of the code because the objective is to see which features effect the win so pca does not help accomplish that goal. Also the data set is small enough so that PCA is not needed. This code is not ready to run since this data is not split yet. However; I left it in since this was on the project proposal.
#
# # Principal Component Analysis
#
# # Set K
# k = 5
#
# pca = PCA(k=k, inputCol="features", outputCol="pcaFeatures")
# pcamodel = pca.fit(df_sp_asm)
#
# df_sp_res = pcamodel.transform(df_sp_asm).select("pcaFeatures",target_variable_name)
# df_sp_res.show(5, truncate=False)
#
# # Converting to Pandas
# df_pd_res = df_sp_res.toPandas()
#
#
# # Splitting Vectorized Column into Columns
# df_sp_final = df_sp_res.withColumn("PCAfeatures", vector_to_array("PCAfeatures")).select([target_variable_name] + [col("PCAfeatures")[i] for i in range(k)])
# df_sp_final.show(5)

# %% [markdown]
# ## Machine Learning Techniques

# %%
Results_Matrix = []

# %%
# Splitting the Data

# Setting the pre-proccessed dataframe
df = df_pd_indexed

X = df.drop(target_variable_name, axis = 1)
y = df[target_variable_name]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %% [markdown]
# ### SVM

# %%
# Running SVM


# Sigmoid was selected  due to the Binary Output
svmachine = SVC(kernel='sigmoid') #sigmoid, poly, rbf, ... 
#svmachine = SVR(kernel='sigmoid')
svmachine.fit(X_train, y_train)

# Predicting
y_pred = svclassifier.predict(y_test)

# Appending
#

# Plotting
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# ### K-Nearest Neighbors

# %%
# Running K-Nearest Neighbors


import time
start_time = time.time()

# Running Model
knn = KNeighborsRegressor(n_neighbors=20, weights='uniform')#‘distance’
knn.fit(X_train, y_train)
    
# Predicting
y_pred_KNN = knn.predict(X_test).reshape(-1,1)

stop_time = time.time() - start_time
print(stop_time)

# %%
# Results for KNN


r2_KNN = r2_score(y_test,y_pred_KNN) 
r2.append(r2_EN)

MSE_KNN = mean_squared_error(y_test, y_pred_KNN)
MSE.append(MSE_KNN)

ME_KNN = max_error(y_test, y_pred_KNN)
ME.append(ME_KNN)

# %% [markdown]
# ### Desicion Trees

# %%
# Running Desicion Tree
DecisionTree = DecisionTreeClassifier()
DecisionTree.fit(X_train, y_train)

# Predicting
Y_pred = DecisionTree.predict(coordinates).reshape(-1,1)

# Appending
# 

# Plotting

# %% [markdown]
# ### Random Forest

# %%
# Random Forest (Max Depth = 5)


start_time = time.time()

# Running Model
RFClassifier = RandomForestClassifier(max_depth= 5, random_state=0)
RFClassifier.fit(X_train,y_train)

# Predicting
y_pred_RF = RFClassifier.predict(X_test)

stop_time = time.time() - start_time
print(stop_time)

# %%
# Results for Random Forest Regressor


r2_RF = r2_score(y_test,y_pred_RF) 
r2.append(r2_RF)

MSE_RF = mean_squared_error(y_test, y_pred_RF)
MSE.append(MSE_RF)

ME_RF = max_error(y_test, y_pred_RF)
ME.append(ME_RF)

# %%
spark.stop()
